# %%
# loading the required libraries needed for data analysis
try:
    import pandas as pd
    import numpy as np
    from mplsoccer import Sbopen
    from statsbombpy import sb
except:
    # %pip install mplsoccer
    # %pip install statsbombpy
    import pandas as pd
    import numpy as np
    from mplsoccer import Sbopen
    from statsbombpy import sb
# Out:
# Requirement already satisfied: mplsoccer in d:\football data\ist652-finalproject\.venv\lib\site-packages (1.2.2)
# Requirement already satisfied: matplotlib>=3.6 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from mplsoccer) (3.8.2)
# Requirement already satisfied: numpy in d:\football data\ist652-finalproject\.venv\lib\site-packages (from mplsoccer) (1.26.2)
# Requirement already satisfied: pandas in d:\football data\ist652-finalproject\.venv\lib\site-packages (from mplsoccer) (2.1.3)
# Requirement already satisfied: pillow in d:\football data\ist652-finalproject\.venv\lib\site-packages (from mplsoccer) (10.1.0)
# Requirement already satisfied: requests in d:\football data\ist652-finalproject\.venv\lib\site-packages (from mplsoccer) (2.31.0)
# Requirement already satisfied: scipy in d:\football data\ist652-finalproject\.venv\lib\site-packages (from mplsoccer) (1.11.4)
# Requirement already satisfied: seaborn in d:\football data\ist652-finalproject\.venv\lib\site-packages (from mplsoccer) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from matplotlib>=3.6->mplsoccer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from pandas->mplsoccer) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from pandas->mplsoccer) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->mplsoccer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->mplsoccer) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->mplsoccer) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->mplsoccer) (2023.11.17)
# Requirement already satisfied: six>=1.5 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mplsoccer) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting statsbombpy
#   Using cached statsbombpy-1.11.0-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: pandas in d:\football data\ist652-finalproject\.venv\lib\site-packages (from statsbombpy) (2.1.3)
# Requirement already satisfied: requests in d:\football data\ist652-finalproject\.venv\lib\site-packages (from statsbombpy) (2.31.0)
# Collecting requests-cache (from statsbombpy)
#   Using cached requests_cache-1.1.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting inflect (from statsbombpy)
#   Using cached inflect-7.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting joblib (from statsbombpy)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pydantic>=1.9.1 (from inflect->statsbombpy)
#   Downloading pydantic-2.5.2-py3-none-any.whl.metadata (65 kB)
#      ---------------------------------------- 0.0/65.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/65.2 kB ? eta -:--:--
#      ----------------------- -------------- 41.0/65.2 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 65.2/65.2 kB 504.3 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in d:\football data\ist652-finalproject\.venv\lib\site-packages (from inflect->statsbombpy) (4.9.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from pandas->statsbombpy) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from pandas->statsbombpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from pandas->statsbombpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from pandas->statsbombpy) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->statsbombpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->statsbombpy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->statsbombpy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests->statsbombpy) (2023.11.17)
# Collecting attrs>=21.2 (from requests-cache->statsbombpy)
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB ? eta 0:00:00
# Collecting cattrs>=22.2 (from requests-cache->statsbombpy)
#   Downloading cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from requests-cache->statsbombpy) (4.1.0)
# Collecting url-normalize>=1.4 (from requests-cache->statsbombpy)
#   Using cached url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.9.1->inflect->statsbombpy)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic>=1.9.1->inflect->statsbombpy)
#   Downloading pydantic_core-2.14.5-cp311-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.5 in d:\football data\ist652-finalproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.16.0)
# Using cached statsbombpy-1.11.0-py3-none-any.whl (16 kB)
# Using cached inflect-7.0.0-py3-none-any.whl (34 kB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached requests_cache-1.1.1-py3-none-any.whl (60 kB)
# Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#    ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#    ---------------------------------------- 0.0/381.9 kB ? eta -:--:--
#    ---------------------------------------- 381.9/381.9 kB 7.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.14.5-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ------------- -------------------------- 0.7/1.9 MB 20.8 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/1.9 MB 22.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 20.0 MB/s eta 0:00:00
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Installing collected packages: url-normalize, pydantic-core, joblib, attrs, annotated-types, pydantic, cattrs, requests-cache, inflect, statsbombpy
# Successfully installed annotated-types-0.6.0 attrs-23.1.0 cattrs-23.2.3 inflect-7.0.0 joblib-1.3.2 pydantic-2.5.2 pydantic-core-2.14.5 requests-cache-1.1.1 statsbombpy-1.11.0 url-normalize-1.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# loading statsbomb to extract data
sbo=Sbopen()

# %%
#Load the competition file
competitions = sbo.competition()

# %%
competitions.head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0               9         27      Germany     1. Bundesliga
# 1              16          4       Europe  Champions League
# 2              16          1       Europe  Champions League
# 3              16          2       Europe  Champions League
# 4              16         27       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2015/2016  2023-08-17T23:51:11.837478                     None
# 1   2018/2019  2023-03-07T12:20:48.118250  2021-06-13T16:17:31.694
# 2   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None  2023-08-17T23:51:11.837478
# 1                None  2023-03-07T12:20:48.118250
# 2                None  2021-01-23T21:55:30.425330
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %%
# filtering La Liga matches from the entire data set
laLiga = competitions[competitions['competition_name']=='La Liga'].reset_index()

# %%
# frinting the first 5 rows of the LA Liga data
laLiga.head()
# Out:
#    index  competition_id  season_id country_name competition_name  \
# 0     35              11         90        Spain          La Liga
# 1     36              11         42        Spain          La Liga
# 2     37              11          4        Spain          La Liga
# 3     38              11          1        Spain          La Liga
# 4     39              11          2        Spain          La Liga
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2020/2021  2023-07-26T14:11:01.312143  2023-07-26T14:15:15.217027
# 1   2019/2020  2023-07-25T00:16:32.999467     2021-06-13T16:17:31.694
# 2   2018/2019  2023-08-03T02:24:43.761907  2021-07-09T14:53:22.103024
# 3   2017/2018  2023-07-24T13:03:48.574627     2021-06-13T16:17:31.694
# 4   2016/2017  2023-07-25T00:14:55.260536     2021-06-13T16:17:31.694
#
#           match_available_360             match_available
# 0  2023-07-26T14:15:15.217027  2023-07-26T14:11:01.312143
# 1                        None  2023-07-25T00:16:32.999467
# 2                        None  2023-08-03T02:24:43.761907
# 3                        None  2023-07-24T13:03:48.574627
# 4                        None  2023-07-25T00:14:55.260536

# %%
# extracting the competition ID for La Laiga
comp_id = laLiga['competition_id'][0]

# %%
# filtering the years Messi played for Barcelona
messiYears = list(range(2004,2022))

# %%
# extracting all the matches played by Messi
messiLaLiga =[]
messiSeasons =[]
for y in messiYears:
    for index, row in laLiga.iterrows():
        if(str(y) in row['season_name']):
            if(row['season_id'] in messiLaLiga):
                pass
            else:
                messiLaLiga.append(row['season_id'])
                messiSeasons.append(y)

# %%
# the competition ID's where messi has played
messiLaLiga
# Out:
# [37, 38, 39, 40, 41, 21, 22, 23, 24, 25, 26, 27, 2, 1, 4, 42, 90]

# %%
# the Years where Messi has played
messiSeasons
# Out:
# [2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020]

# %%
# extracting all the data with the given years and competition ID
temp = sbo.match(competition_id=comp_id,season_id=1)

# %%
#Load the list of matches for this competition
col = temp.columns.tolist()
matches = pd.DataFrame(columns=col)
count = 0
for i in messiLaLiga:
    match = sbo.match(competition_id=comp_id,season_id=i)
    match['season'] = messiSeasons[count]
    count = count+1
    matches = pd.concat([matches, match])
# Out:
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\3864490074.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   matches = pd.concat([matches, match])

# %%
matches.reset_index()
# Out:
#      index match_id match_date            kick_off home_score away_score  \
# 0        0    68314 2004-12-04 2004-12-04 20:00:00          4          0
# 1        1    68313 2004-10-24 2004-10-24 21:00:00          3          0
# 2        2    68316 2005-05-01 2005-05-01 19:00:00          2          0
# 3        3    68315 2004-12-21 2004-12-21 20:00:00          2          1
# 4        4    69153 2004-12-11 2004-12-11 20:00:00          1          2
# ..     ...      ...        ...                 ...        ...        ...
# 862     30  3773547 2020-11-29 2020-11-29 14:00:00          4          0
# 863     31  3773415 2021-02-21 2021-02-21 14:00:00          1          1
# 864     32  3764440 2021-02-24 2021-02-24 19:00:00          3          0
# 865     33  3773689 2021-04-25 2021-04-25 16:15:00          1          2
# 866     34  3773477 2020-11-07 2020-11-07 16:15:00          5          2
#
#     match_status match_status_360               last_updated  \
# 0      available        scheduled 2020-07-29 05:00:00.000000
# 1      available        scheduled 2020-07-29 05:00:00.000000
# 2      available        scheduled 2020-07-29 05:00:00.000000
# 3      available        scheduled 2020-07-29 05:00:00.000000
# 4      available        scheduled 2020-07-29 05:00:00.000000
# ..           ...              ...                        ...
# 862    available        available 2020-11-30 09:14:36.663981
# 863    available        available 2023-07-25 03:10:18.051218
# 864    available        available 2023-07-25 03:06:46.373172
# 865    available        available 2022-12-02 09:12:52.250855
# 866    available        available 2023-07-25 03:59:53.393191
#
#               last_updated_360  ... competition_stage_name stadium_id  \
# 0   2021-06-13 16:17:31.694000  ...         Regular Season        342
# 1   2021-06-13 16:17:31.694000  ...         Regular Season        342
# 2   2021-06-13 16:17:31.694000  ...         Regular Season        342
# 3   2021-06-13 16:17:31.694000  ...         Regular Season        342
# 4   2021-06-13 16:17:31.694000  ...         Regular Season       4448
# ..                         ...  ...                    ...        ...
# 862 2022-08-04 12:00:00.000000  ...         Regular Season        342
# 863 2023-07-25 03:17:10.679932  ...         Regular Season        342
# 864 2023-07-25 03:12:39.582957  ...         Regular Season        342
# 865 2023-04-28 00:44:33.357677  ...         Regular Season        361
# 866 2023-07-25 04:21:10.335828  ...         Regular Season        342
#
#                 stadium_name stadium_country_id stadium_country_name  \
# 0           Spotify Camp Nou                214                Spain
# 1           Spotify Camp Nou                214                Spain
# 2           Spotify Camp Nou                214                Spain
# 3           Spotify Camp Nou                214                Spain
# 4    Estadio Carlos Belmonte                214                Spain
# ..                       ...                ...                  ...
# 862         Spotify Camp Nou                214                Spain
# 863         Spotify Camp Nou                214                Spain
# 864         Spotify Camp Nou                214                Spain
# 865   Estadio de la Cerámica                214                Spain
# 866         Spotify Camp Nou                214                Spain
#
#     referee_id                   referee_name referee_country_id  \
# 0          993             José Omar Losantos                214
# 1          994    Vicente José Lizondo Cortés                214
# 2         2535        Carlos Velasco Carballo                214
# 3          222       David Fernández Borbalan                214
# 4         1007          Alfonso Perez Burrull                214
# ..         ...                            ...                ...
# 862      180.0     Antonio Miguel Mateu Lahoz              214.0
# 863     2434.0          Juan Martínez Munuera              214.0
# 864     2634.0  Isidro Díaz de Mera Escuderos              214.0
# 865     2728.0        Carlos del Cerro Grande              214.0
# 866        NaN                            NaN                NaN
#
#     referee_country_name  season
# 0                  Spain  2004.0
# 1                  Spain  2004.0
# 2                  Spain  2004.0
# 3                  Spain  2004.0
# 4                  Spain  2004.0
# ..                   ...     ...
# 862                Spain  2020.0
# 863                Spain  2020.0
# 864                Spain  2020.0
# 865                Spain  2020.0
# 866                  NaN  2020.0
#
# [867 rows x 54 columns]

# %%
# extracting the column names
col = matches.columns

# %%
# filtering the columns needed for analysis
colKeep = ['match_id', 'match_date', 'match_week', 'season', 'home_score', 'away_score', 'home_team_name', 'home_team_managers_name'
           , 'away_team_name', 'away_team_managers_name', 'stadium_name', 'referee_name']

# %%
# deleting the remaining columns from the data
colDel = [x for x in col if x not in colKeep]

# %%
matches = matches.drop(colDel,axis=1)

# %%
# filtering Barcelona's matches from the dataset
barca = matches[(matches['home_team_name']=='Barcelona') | (matches['away_team_name'] == 'Barcelona')]

# %%
barca
# Out:
#    match_id match_date home_score away_score match_week home_team_name  \
# 0     68314 2004-12-04          4          0         14      Barcelona
# 1     68313 2004-10-24          3          0          8      Barcelona
# 2     68316 2005-05-01          2          0         34      Barcelona
# 3     68315 2004-12-21          2          1         17      Barcelona
# 4     69153 2004-12-11          1          2         15       Albacete
# ..      ...        ...        ...        ...        ...            ...
# 30  3773547 2020-11-29          4          0         11      Barcelona
# 31  3773415 2021-02-21          1          1         24      Barcelona
# 32  3764440 2021-02-24          3          0          1      Barcelona
# 33  3773689 2021-04-25          1          2         32     Villarreal
# 34  3773477 2020-11-07          5          2          9      Barcelona
#
#        home_team_managers_name away_team_name  \
# 0               Frank Rijkaard         Málaga
# 1               Frank Rijkaard        Osasuna
# 2               Frank Rijkaard       Albacete
# 3               Frank Rijkaard     Levante UD
# 4   José Manuel González López      Barcelona
# ..                         ...            ...
# 30               Ronald Koeman        Osasuna
# 31               Ronald Koeman          Cádiz
# 32               Ronald Koeman          Elche
# 33        Unai Emery Etxegoien      Barcelona
# 34               Ronald Koeman     Real Betis
#
#              away_team_managers_name             stadium_name  \
# 0       Gregorio Manzano Ballesteros         Spotify Camp Nou
# 1            Javier Aguirre Onaindía         Spotify Camp Nou
# 2       Martín Monteagudo Monteagudo         Spotify Camp Nou
# 3                     Bernd Schuster         Spotify Camp Nou
# 4                     Frank Rijkaard  Estadio Carlos Belmonte
# ..                               ...                      ...
# 30         Jagoba Arrasate Elustondo         Spotify Camp Nou
# 31               Álvaro Cervera Díaz         Spotify Camp Nou
# 32          Francisco Escriba Segura         Spotify Camp Nou
# 33                     Ronald Koeman   Estadio de la Cerámica
# 34  Manuel Luis Pellegrini Ripamonti         Spotify Camp Nou
#
#                      referee_name  season
# 0              José Omar Losantos  2004.0
# 1     Vicente José Lizondo Cortés  2004.0
# 2         Carlos Velasco Carballo  2004.0
# 3        David Fernández Borbalan  2004.0
# 4           Alfonso Perez Burrull  2004.0
# ..                            ...     ...
# 30     Antonio Miguel Mateu Lahoz  2020.0
# 31          Juan Martínez Munuera  2020.0
# 32  Isidro Díaz de Mera Escuderos  2020.0
# 33        Carlos del Cerro Grande  2020.0
# 34                            NaN  2020.0
#
# [525 rows x 12 columns]

# %%
# extracting the home team manager, away team manager, home team, away team , stadium, and refree
manager=[]
oppManager=[]
homeTeam = []
awayTeam = []
stadium =[]
referee=[]
for index,row in barca.iterrows():
    if((type(row['home_team_managers_name'])==str)):
        if(row['home_team_name']=='Barcelona'):
            manager.append(row['home_team_managers_name'])
        else:
            manager.append(row['away_team_managers_name'])
    else:
        manager.append('')
    if((type(row['home_team_managers_name'])==str)):
        if(row['home_team_name']=='Barcelona'):
            oppManager.append(row['away_team_managers_name'])
        else:
            oppManager.append(row['home_team_managers_name'])
    else:
        oppManager.append('')

# %%
manager
# Out:
# ['Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  '',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  '',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  '',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  '',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  '',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Frank Rijkaard',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  '',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  '',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  '',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  '',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  'Josep Guardiola i Sala',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Francesc Vilanova i Bayo',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Francesc Vilanova i Bayo',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Gerardo Daniel Martino',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  '',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Luis Enrique Martínez García',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Ernesto Valverde Tejedor',
#  'Enrique Setién Solar',
#  'Ernesto Valverde Tejedor',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman',
#  'Ronald Koeman']

# %%
# extracting manager information
for index, row in barca.iterrows():
    if(row['home_team_name']=='Barcelona'):
        row['home_team_managers_name'] = manager[index]
        row['away_team_managers_name'] = oppManager[index]
    else:
        row['home_team_managers_name'] = oppManager[index]
        row['away_team_managers_name'] = manager[index]

# %%
# imputing missing values of manager
for index,row in matches.iterrows():
    if(row['home_team_name']=='Barcelona'):
        if(row['home_team_managers_name']==''):
            if(manager[index-1] != '' and manager[index+1]!='' and manager[index-1]==manager[index+1]):
                manager[index] = manager[index-1]
    else:
        if(row['away_team_managers_name']==''):
            if(manager[index-1] != '' and manager[index+1]!='' and manager[index-1]==manager[index+1]):
                manager[index] = manager[index-1]

# %%
for index, row in barca.iterrows():
    if(row['home_team_name']=='Barcelona'):
        row['home_team_managers_name'] = manager
        row['away_team_managers_name'] = oppManager
    else:
        row['home_team_managers_name'] = oppManager
        row['away_team_managers_name'] = manager

# %%
barca[barca['away_team_managers_name']=='']
# Out:
# Empty DataFrame
# Columns: [match_id, match_date, home_score, away_score, match_week, home_team_name, home_team_managers_name, away_team_name, away_team_managers_name, stadium_name, referee_name, season]
# Index: []

# %%
barca.head(1)
# Out:
#   match_id match_date home_score away_score match_week home_team_name  \
# 0    68314 2004-12-04          4          0         14      Barcelona
#
#   home_team_managers_name away_team_name       away_team_managers_name  \
# 0          Frank Rijkaard         Málaga  Gregorio Manzano Ballesteros
#
#        stadium_name        referee_name  season
# 0  Spotify Camp Nou  José Omar Losantos  2004.0

# %%
# subsetting the dataframe with the needed columns
barca=barca[['season','match_id','match_week','match_date','home_score','away_score','home_team_name','home_team_managers_name','away_team_name','away_team_managers_name','stadium_name','referee_name']]

# %%
# converting Barcelonas's match ID to list
match_id = barca['match_id'].to_list()

# %%
# extrating the starting 11 players of all the Barcelona Match
temp = sbo.lineup(match_id=68314)[sbo.lineup(match_id=68314)['team_name']=='Barcelona']

# %%
# extracting all the matched played by Messi
a =temp[temp['player_nickname']=='Lionel Messi']['match_id']

# %%
messiMatchID =[]
for i in match_id:
    lineup = sbo.lineup(match_id=i)
    mid = lineup[lineup['player_nickname']=='Lionel Messi']['match_id'].to_list()
    if(len(mid)!=0):
        messiMatchID.append(mid[0])

# %%
# extrating all the Info related to Messi's matches
messiMatches = barca[barca['match_id'].isin(messiMatchID)]

# %%
messiMatches
# Out:
#     season match_id match_week match_date home_score away_score  \
# 0   2004.0    68314         14 2004-12-04          4          0
# 1   2004.0    68313          8 2004-10-24          3          0
# 2   2004.0    68316         34 2005-05-01          2          0
# 3   2004.0    68315         17 2004-12-21          2          1
# 4   2004.0    69153         15 2004-12-11          1          2
# ..     ...      ...        ...        ...        ...        ...
# 30  2020.0  3773547         11 2020-11-29          4          0
# 31  2020.0  3773415         24 2021-02-21          1          1
# 32  2020.0  3764440          1 2021-02-24          3          0
# 33  2020.0  3773689         32 2021-04-25          1          2
# 34  2020.0  3773477          9 2020-11-07          5          2
#
#    home_team_name     home_team_managers_name away_team_name  \
# 0       Barcelona              Frank Rijkaard         Málaga
# 1       Barcelona              Frank Rijkaard        Osasuna
# 2       Barcelona              Frank Rijkaard       Albacete
# 3       Barcelona              Frank Rijkaard     Levante UD
# 4        Albacete  José Manuel González López      Barcelona
# ..            ...                         ...            ...
# 30      Barcelona               Ronald Koeman        Osasuna
# 31      Barcelona               Ronald Koeman          Cádiz
# 32      Barcelona               Ronald Koeman          Elche
# 33     Villarreal        Unai Emery Etxegoien      Barcelona
# 34      Barcelona               Ronald Koeman     Real Betis
#
#              away_team_managers_name             stadium_name  \
# 0       Gregorio Manzano Ballesteros         Spotify Camp Nou
# 1            Javier Aguirre Onaindía         Spotify Camp Nou
# 2       Martín Monteagudo Monteagudo         Spotify Camp Nou
# 3                     Bernd Schuster         Spotify Camp Nou
# 4                     Frank Rijkaard  Estadio Carlos Belmonte
# ..                               ...                      ...
# 30         Jagoba Arrasate Elustondo         Spotify Camp Nou
# 31               Álvaro Cervera Díaz         Spotify Camp Nou
# 32          Francisco Escriba Segura         Spotify Camp Nou
# 33                     Ronald Koeman   Estadio de la Cerámica
# 34  Manuel Luis Pellegrini Ripamonti         Spotify Camp Nou
#
#                      referee_name
# 0              José Omar Losantos
# 1     Vicente José Lizondo Cortés
# 2         Carlos Velasco Carballo
# 3        David Fernández Borbalan
# 4           Alfonso Perez Burrull
# ..                            ...
# 30     Antonio Miguel Mateu Lahoz
# 31          Juan Martínez Munuera
# 32  Isidro Díaz de Mera Escuderos
# 33        Carlos del Cerro Grande
# 34                            NaN
#
# [520 rows x 12 columns]

# %%
# extracting the opponents info for the matches played by Messi
opponent =[]
for index,row in messiMatches.iterrows():
    if(row['home_team_name']=='Barcelona'):
        opponent.append(row['away_team_name'])
    elif(row['away_team_name']=='Barcelona'):
        opponent.append(row['home_team_name'])

messiMatches['opponent'] = opponent
# Out:
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\3788186772.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   messiMatches['opponent'] = opponent

# %%
#messiMatches.to_csv('messiMatches.csv',index=False)

# %%
# grouping the matches based on the season
messiMatchesG = messiMatches.groupby('season').agg(lambda x: list(x)).reset_index()

# %%
lineup = sb.lineups(match_id=68314)['Barcelona']

# %%
# extracting Messi's player ID from the lineup
messiID = lineup[lineup['player_nickname']=='Lionel Messi']['player_id'][1]

# %%
messiID = float(messiID)

# %%
messiID
# Out:
# 5503.0

# %%
# creatign a temp variable to view data for the particular season
tempE = sb.competition_events(
            country="Spain",
            division= "La Liga",
            season="1973/1974"
        )

# %%
# iterating through all the seasons and creating a data frame of all the matches played by Messi
col = tempE.columns.tolist()
eventsMessi = pd.DataFrame(columns=col)
i=0
for season in laLiga['season_name']:
    if(season!='1973/1974'):
        event = sb.competition_events(
            country="Spain",
            division= "La Liga",
            season=season
        )
        event['season'] = season
        eventsMessi = pd.concat([eventsMessi, event[event['player_id']==messiID]])
    i=i+1
# Out:
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   eventsMessi = pd.concat([eventsMessi, event[event['player_id']==messiID]])
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season
# C:\Users\yashaswi\AppData\Local\Temp\ipykernel_29056\1092833125.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   event['season'] = season

# %%
eventsMessi = eventsMessi.reset_index()

# %%
eventsMessi[['x_start','y_start']] = eventsMessi['location'].apply(pd.Series)
eventsMessi[['x_end','y_end']] = eventsMessi['pass_end_location'].apply(pd.Series)
eventsMessi[['x_carry_end','y_carry_end']] = eventsMessi['carry_end_location'].apply(pd.Series)

# %%
eventsMessi = eventsMessi.drop(['level_0'],axis=1)

# %%
#eventsMessi.to_csv('eventsMessi.csv',index=False)
